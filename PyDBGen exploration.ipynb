# %% [markdown]
# PyDBGen Exploration for DataKind Synthetic Data
# https://opensource.com/article/18/11/pydbgen-random-database-table-generator

# %% [markdown]
# Install in terminal using:
# pip install pydbgen
# pip install --upgrade pip
# pip install Faker

# %%
import pydbgen
from pydbgen import pydbgen

from faker import Faker
fake = Faker()

# %%
from faker.providers.person import Provider

help(Provider)
# Out:
# Help on class Provider in module faker.providers.person:
#
# class Provider(faker.providers.BaseProvider)
#  |  Method resolution order:
#  |      Provider
#  |      faker.providers.BaseProvider
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  first_name(self)
#  |
#  |  first_name_female(self)
#  |
#  |  first_name_male(self)
#  |
#  |  first_name_nonbinary(self)
#  |
#  |  language_name(self)
#  |      Generate a random i18n language name (e.g. English).
#  |
#  |  last_name(self)
#  |
#  |  last_name_female(self)
#  |
#  |  last_name_male(self)
#  |
#  |  last_name_nonbinary(self)
#  |
#  |  name(self)
#  |      :example 'John Doe'
#  |
#  |  name_female(self)
#  |
#  |  name_male(self)
#  |
#  |  name_nonbinary(self)
#  |
#  |  prefix(self)
#  |
#  |  prefix_female(self)
#  |
#  |  prefix_male(self)
#  |
#  |  prefix_nonbinary(self)
#  |
#  |  suffix(self)
#  |
#  |  suffix_female(self)
#  |
#  |  suffix_male(self)
#  |
#  |  suffix_nonbinary(self)
#  |
# ...

# %%
myDB=pydbgen.pydb()

# %%
symptomSet = {'none', 'cough', 'fever', 'aches', 'chills', 'headache', 'nausea', 'vomiting'} #could be a file

# %%
Faker.seed(0)
for _ in range(5):
    print(fake.name())
    print(fake.locale())    #ability to set various locales
    print(fake.random_choices(symptomSet))
# Out:
# Norma Fisher
# hy_AM
# ['headache', 'none', 'headache', 'vomiting', 'headache', 'nausea', 'nausea']
# Brandon Lloyd
# sd_IN
# ['fever', 'fever', 'none', 'vomiting', 'aches']
# Eugene Bowman
# gd_GB
# ['none', 'vomiting', 'none', 'aches', 'fever', 'cough', 'chills', 'none']
# April Snyder
# kw_GB
# ['cough', 'fever', 'headache', 'nausea', 'none', 'nausea']
# Anna Kaiser
# ro_RO
# ['vomiting', 'vomiting']
